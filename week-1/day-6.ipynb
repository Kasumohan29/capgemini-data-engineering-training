# %% [markdown]
# ###9. Rank all employees based on salary (highest first).

# %%
# %sql
DROP TABLE IF EXISTS employees;
CREATE TABLE employees (
    emp_id INT,
    emp_name VARCHAR(50),
    department VARCHAR(50),
    salary INT,
    join_date DATE
);
INSERT INTO employees VALUES
(1, 'Amit', 'Chennai', 2000, '2023-01-01'),
(2, 'Ravi', 'Hyderabad', 1500, '2023-01-02'),
(3, 'Sneha', 'Chennai', 3000, '2023-01-03'),
(4, 'Kiran', 'Bangalore', 2500, '2023-01-04'),
(5, 'Priya', 'Chennai', 2000, '2023-01-05'),
(6, 'Arjun', 'Hyderabad', 1800, '2023-01-06'),
(7, 'Neha', 'Bangalore', 2200, '2023-01-07'),
(8, 'Vikas', 'Chennai', 3000, '2023-01-08'),
(9, 'Anjali', 'Hyderabad', 1700, '2023-01-09'),
(10, 'Rahul', 'Bangalore', 2600, '2023-01-10'),
(11, 'Suresh', 'Chennai', 2800, '2023-01-11'),
(12, 'Pooja', 'Hyderabad', 1600, '2023-01-12'),
(13, 'Manoj', 'Bangalore', 2400, '2023-01-13'),
(14, 'Divya', 'Chennai', 2100, '2023-01-14'),
(15, 'Karthik', 'Hyderabad', 1900, '2023-01-15'),
(16, 'Meena', 'Bangalore', 2300, '2023-01-16'),
(17, 'Raj', 'Chennai', 2700, '2023-01-17'),
(18, 'Simran', 'Hyderabad', 2000, '2023-01-18'),
(19, 'Deepak', 'Bangalore', 2500, '2023-01-19'),
(20, 'Nisha', 'Chennai', 2600, '2023-01-20');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>20</td><td>20</td></tr></tbody></table></div>

# %%
# %sql
SELECT 
    emp_id,
    emp_name,
    salary,
    RANK() OVER (ORDER BY salary DESC) AS rank_salary
FROM employees;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ###10. Rank employees within each department based on salary.

# %%
# %sql
select emp_id,emp_name,department,salary, RANK() OVer (Partition by department order by salary desc)  as dept_rank from employees;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ###11. Rank employees based on joining date (latest gets rank 1).

# %%
# %sql
select emp_name,RANK() over (order by join_date DESC) as emp_rank from employees
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ###
# 12. Rank orders based on order amount (highest first).

# %%
# %sql
DROP TABLE IF EXISTS orders;
CREATE TABLE orders (
    order_id INT,
    customer_id VARCHAR(10),
    customer_name VARCHAR(50),
    city VARCHAR(50),
    order_date DATE,
    order_amount DECIMAL(10,2)
);

INSERT INTO orders VALUES
(101, 'C001', 'Ravi',   'Chennai',  '2023-01-10', 250.50),
(102, 'C002', 'Anjali', 'Mumbai',   '2023-02-15', 300.00),
(103, 'C003', 'Kiran',  'Chennai',  '2023-03-05', 150.75),
(104, 'C004', 'Meena',  'Delhi',    '2023-01-25', 500.20),
(105, 'C005', 'Arjun',  'Mumbai',   '2023-03-20', 700.00),
(106, 'C006', 'Priya',  'Delhi',    '2023-02-05', 120.00);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>6</td><td>6</td></tr></tbody></table></div>

# %%
# %sql

select *,RANK() over (order by order_amount DESC) As Order_rank from orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ###13. Rank orders within each city based on order amount

# %%
# %sql
select order_id,city,order_date,order_amount,RANK() over (partition by city order by order_amount) AS rank_order from orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>city</th><th>order_date</th><th>order_amount</th><th>rank_order</th></tr></thead><tbody><tr><td>103</td><td>Chennai</td><td>2023-03-05</td><td>150.75</td><td>1</td></tr><tr><td>101</td><td>Chennai</td><td>2023-01-10</td><td>250.50</td><td>2</td></tr><tr><td>106</td><td>Delhi</td><td>2023-02-05</td><td>120.00</td><td>1</td></tr><tr><td>104</td><td>Delhi</td><td>2023-01-25</td><td>500.20</td><td>2</td></tr><tr><td>102</td><td>Mumbai</td><td>2023-02-15</td><td>300.00</td><td>1</td></tr><tr><td>105</td><td>Mumbai</td><td>2023-03-20</td><td>700.00</td><td>2</td></tr></tbody></table></div>

# %% [markdown]
# ###16. Rank orders within each city based on order date.

# %%
# %sql
SELECT *,
RANK() OVER (PARTITION BY city ORDER BY order_date ASC) AS rank_order
FROM orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ###17. Assign dense rank to employees based on salary (highest first).

# %%
# %sql
SELECT *,
DENSE_RANK() OVER (ORDER BY salary DESC) AS rank_salary
FROM employees;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ###19. Assign dense rank to employees based on joining date

# %%
# %sql
SELECT *,
DENSE_RANK() OVER (ORDER BY join_date DESC) AS rank_join
FROM employees;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ###23. Assign dense rank within department based on joining date.

# %%
# %sql
SELECT*,
Dense_rank() over (partition by department order by join_date DESC ) As rank_join
From employees
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ###DATE & TIMESTAMP FUNCTIONS IN MYSQL (DETAILED)

# %%
# %sql
DROP TABLE IF EXISTS `order`;

DROP TABLE IF EXISTS orders;

CREATE TABLE orders (
    order_id INT,
    customer_name STRING,
    order_date DATE,
    order_timestamp TIMESTAMP,
    delivery_date DATE,
    order_amount DECIMAL(10,2)
);

INSERT INTO orders VALUES
(1, 'Karthik', '2024-01-15', '2024-01-15 10:30:45', '2024-01-20', 2500.00),
(2, 'Veena', '2024-02-18', '2024-02-18 18:45:20', '2024-02-22', 3200.50),
(3, 'Ravi', '2024-03-02', '2024-03-02 09:15:10', '2024-03-08', 4100.75),
(4, 'Anil', '2024-03-09', '2024-03-09 14:05:55', '2024-03-15', 1800.00),
(5, 'Suresh', '2024-01-07', '2024-01-07 23:55:00', '2024-01-12', 2900.00);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

# %% [markdown]
# ###CURRENT DATE & TIME FUNCTIONS

# %%
# %sql

SELECT CURRENT_TIMESTAMP();
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CURRENT_TIMESTAMP()</th></tr></thead><tbody><tr><td>2026-04-20T08:52:39.137Z</td></tr></tbody></table></div>

# %% [markdown]
# ###Extracting Year,Month,Date

# %%
# %sql
SELECT
YEAR(order_date),
MONTH(order_date),
DAY(order_date)
FROM orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>YEAR(order_date)</th><th>MONTH(order_date)</th><th>DAY(order_date)</th></tr></thead><tbody><tr><td>2024</td><td>1</td><td>15</td></tr><tr><td>2024</td><td>2</td><td>18</td></tr><tr><td>2024</td><td>3</td><td>2</td></tr><tr><td>2024</td><td>3</td><td>9</td></tr><tr><td>2024</td><td>1</td><td>7</td></tr></tbody></table></div>

# %%
# %sql
SELECT
EXTRACT(YEAR FROM order_date),
EXTRACT(MONTH FROM order_date),
EXTRACT(DAY FROM order_date)
FROM orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>EXTRACT(YEARFROMorder_date)</th><th>EXTRACT(MONTHFROMorder_date)</th><th>EXTRACT(DAYFROMorder_date)</th></tr></thead><tbody><tr><td>2024</td><td>1</td><td>15</td></tr><tr><td>2024</td><td>2</td><td>18</td></tr><tr><td>2024</td><td>3</td><td>2</td></tr><tr><td>2024</td><td>3</td><td>9</td></tr><tr><td>2024</td><td>1</td><td>7</td></tr></tbody></table></div>

# %%
# %sql
SELECT
MONTHNAME(order_date),
DAYNAME(order_date)
FROM orders
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>MONTHNAME(order_date)</th><th>DAYNAME(order_date)</th></tr></thead><tbody><tr><td>Jan</td><td>Mon</td></tr><tr><td>Feb</td><td>Sun</td></tr><tr><td>Mar</td><td>Sat</td></tr><tr><td>Mar</td><td>Sat</td></tr><tr><td>Jan</td><td>Sun</td></tr></tbody></table></div>

# %% [markdown]
# ###8. WEEKDAY AND DAY OF WEEK

# %% [markdown]
# ###

# %%
# %sql
SELECT
WEEKDAY(order_date),
DAYOFWEEK(order_date)
FROM orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>WEEKDAY(order_date)</th><th>DAYOFWEEK(order_date)</th></tr></thead><tbody><tr><td>0</td><td>2</td></tr><tr><td>6</td><td>1</td></tr><tr><td>5</td><td>7</td></tr><tr><td>5</td><td>7</td></tr><tr><td>6</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
SELECT order_id, order_date
FROM orders
WHERE DAYOFWEEK(order_date) BETWEEN 2 AND 6;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>order_date</th></tr></thead><tbody><tr><td>1</td><td>2024-01-15</td></tr></tbody></table></div>

# %%
# %sql
SELECT order_date, ADD_months(order_date, 5 )
FROM orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_date</th><th>ADD_months(order_date,5)</th></tr></thead><tbody><tr><td>2024-01-15</td><td>2024-06-15</td></tr><tr><td>2024-02-18</td><td>2024-07-18</td></tr><tr><td>2024-03-02</td><td>2024-08-02</td></tr><tr><td>2024-03-09</td><td>2024-08-09</td></tr><tr><td>2024-01-07</td><td>2024-06-07</td></tr></tbody></table></div>

# %%
# %sql

SELECT 
    order_date, 
    ADD_MONTHS(order_date, 12 * 5) AS new_date
FROM orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_date</th><th>new_date</th></tr></thead><tbody><tr><td>2024-01-15</td><td>2029-01-15</td></tr><tr><td>2024-02-18</td><td>2029-02-18</td></tr><tr><td>2024-03-02</td><td>2029-03-02</td></tr><tr><td>2024-03-09</td><td>2029-03-09</td></tr><tr><td>2024-01-07</td><td>2029-01-07</td></tr></tbody></table></div>

# %%
# %sql

select
    order_date,
    DATE_SUB(order_date, DAY(order_date) - 1) AS first_day_of_month
FROM orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_date</th><th>first_day_of_month</th></tr></thead><tbody><tr><td>2024-01-15</td><td>2024-01-01</td></tr><tr><td>2024-02-18</td><td>2024-02-01</td></tr><tr><td>2024-03-02</td><td>2024-03-01</td></tr><tr><td>2024-03-09</td><td>2024-03-01</td></tr><tr><td>2024-01-07</td><td>2024-01-01</td></tr></tbody></table></div>

# %% [markdown]
# ###Setting DATE FORMAT

# %%
# %sql
SELECT 
    DATE_FORMAT(order_date, 'dd-MM-yyyy') AS formatted_date
FROM orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>formatted_date</th></tr></thead><tbody><tr><td>15-01-2024</td></tr><tr><td>18-02-2024</td></tr><tr><td>02-03-2024</td></tr><tr><td>09-03-2024</td></tr><tr><td>07-01-2024</td></tr></tbody></table></div>

# %% [markdown]
# ###
